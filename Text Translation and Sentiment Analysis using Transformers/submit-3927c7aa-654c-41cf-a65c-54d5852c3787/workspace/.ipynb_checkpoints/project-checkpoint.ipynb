# %% [markdown]
# # Text Translation and Sentiment Analysis using Transformers

# %% [markdown]
# ## Project Overview:
#
# The objective of this project is to analyze the sentiment of movie reviews in three different languages - English, French, and Spanish. We have been given 30 movies, 10 in each language, along with their reviews and synopses in separate CSV files named `movie_reviews_eng.csv`, `movie_reviews_fr.csv`, and `movie_reviews_sp.csv`.
#
# - The first step of this project is to convert the French and Spanish reviews and synopses into English. This will allow us to analyze the sentiment of all reviews in the same language. We will be using pre-trained transformers from HuggingFace to achieve this task.
#
# - Once the translations are complete, we will create a single dataframe that contains all the movies along with their reviews, synopses, and year of release in all three languages. This dataframe will be used to perform sentiment analysis on the reviews of each movie.
#
# - Finally, we will use pretrained transformers from HuggingFace to analyze the sentiment of each review. The sentiment analysis results will be added to the dataframe. The final dataframe will have 30 rows
#
#
# The output of the project will be a CSV file with a header row that includes column names such as **Title**, **Year**, **Synopsis**, **Review**, **Review Sentiment**, and **Original Language**. The **Original Language** column will indicate the language of the review and synopsis (*en/fr/sp*) before translation. The dataframe will consist of 30 rows, with each row corresponding to a movie.

# %%
# imports
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer
from transformers import pipeline

# %% [markdown]
# ### Get data from `.csv` files and then preprocess data

# %%
# use the `pd.read_csv()` function to read the movie_review_*.csv files into 3 separate pandas dataframes

# Note: All the dataframes would have different column names. For testing purposes
# you should have the following column names/headers -> [Title, Year, Synopsis, Review]

# Get data from .csv files and then preprocess data
def preprocess_data() -> pd.DataFrame:
    """
    Reads movie data from .csv files, map column names, add the "Original Language" column,
    and finally concatenate in one resultant dataframe called "df".
    """
    # Read the CSV files into pandas dataframes
    df_eng = pd.read_csv("data/movie_reviews_eng.csv")
    df_fr = pd.read_csv("data/movie_reviews_fr.csv")
    df_sp = pd.read_csv("data/movie_reviews_sp.csv")
    
    # Rename columns to have consistent names across dataframes
    df_eng.columns = ['Title', 'Year', 'Synopsis', 'Review']
    df_fr.columns = ['Title', 'Year', 'Synopsis', 'Review']
    df_sp.columns = ['Title', 'Year', 'Synopsis', 'Review']
    
    # Add "Original Language" column
    df_eng['Original Language'] = 'en'
    df_fr['Original Language'] = 'fr'
    df_sp['Original Language'] = 'sp'
    
    # Concatenate all dataframes
    df = pd.concat([df_eng, df_fr, df_sp], ignore_index=True)
    
    return df

df = preprocess_data()

# %%
df.sample(10)
# Out:
#                              Title         Year  \
# 11                    Intouchables         2011
# 3                   The Godfather          1972
# 13                   Les Choristes         2004
# 2                     Forrest Gump         1994
# 18       Les Visiteurs en Amérique         2000
# 16  La Tour Montparnasse Infernale         2001
# 22               Y tu mamá también         2001
# 4                        Inception         2010
# 21                La Casa de Papel  (2017-2021)
# 17     Astérix aux Jeux Olympiques         2008
#
#                                              Synopsis  \
# 11  Ce film raconte l'histoire de l'amitié improba...
# 3   Don Vito Corleone (Marlon Brando) is the head ...
# 13  Ce film raconte l'histoire d'un professeur de ...
# 2   Forrest Gump (Tom Hanks) is a simple man with ...
# 18  Dans cette suite de la comédie française Les V...
# 16  Deux employés de bureau incompétents se retrou...
# 22  Dos amigos adolescentes (Gael García Bernal y ...
# 4   Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 21  Esta serie de televisión española sigue a un g...
# 17  Dans cette adaptation cinématographique de la ...
#
#                                                Review Original Language
# 11  "Intouchables est un film incroyablement touch...                fr
# 3   "The Godfather is a classic movie that stands ...                en
# 13  "Les Choristes est un film magnifique qui vous...                fr
# 2   "Forrest Gump is a heartwarming and inspiratio...                en
# 18  "Le film est une perte de temps totale. Les bl...                fr
# 16  "Je ne peux pas croire que j'ai perdu du temps...                fr
# 22  "Y tu mamá también es una película que se qued...                sp
# 4   "Inception is a mind-bending and visually stun...                en
# 21  "La Casa de Papel es una serie emocionante y a...                sp
# 17  "Ce film est une déception totale. Les blagues...                fr

# %% [markdown]
# ### Text translation
#
# Translate the **Review** and **Synopsis** column values to English.

# %%
# load translation models and tokenizers
fr_en_model_name = 'Helsinki-NLP/opus-mt-fr-en'
es_en_model_name = 'Helsinki-NLP/opus-mt-es-en'

fr_en_model = MarianMTModel.from_pretrained(fr_en_model_name)
es_en_model = MarianMTModel.from_pretrained(es_en_model_name)
fr_en_tokenizer = MarianTokenizer.from_pretrained(fr_en_model_name)
es_en_tokenizer = MarianTokenizer.from_pretrained(es_en_model_name)

def translate(text: str, model, tokenizer) -> str:
    """
    Function to translate a text using a model and tokenizer.
    """
    # Encode the text using the tokenizer
    inputs = tokenizer(text, return_tensors="pt", padding=True)
    
    # Generate the translation using the model
    outputs = model.generate(**inputs)
    
    # Decode the generated output and return the translated text
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded
# Out:
# Downloading config.json: 100%|██████████| 1.42k/1.42k [00:00<00:00, 6.00MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 301M/301M [00:02<00:00, 149MB/s]
# Downloading generation_config.json: 100%|██████████| 293/293 [00:00<00:00, 1.15MB/s]
# Downloading config.json: 100%|██████████| 1.44k/1.44k [00:00<00:00, 4.59MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 312M/312M [00:02<00:00, 151MB/s]
# Downloading generation_config.json: 100%|██████████| 293/293 [00:00<00:00, 1.08MB/s]
# Downloading source.spm: 100%|██████████| 802k/802k [00:00<00:00, 13.8MB/s]
# Downloading target.spm: 100%|██████████| 778k/778k [00:00<00:00, 36.4MB/s]
# Downloading vocab.json: 100%|██████████| 1.34M/1.34M [00:00<00:00, 36.1MB/s]
# Downloading tokenizer_config.json: 100%|██████████| 42.0/42.0 [00:00<00:00, 130kB/s]
# /opt/venv/lib/python3.10/site-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading source.spm: 100%|██████████| 826k/826k [00:00<00:00, 6.21MB/s]
# Downloading target.spm: 100%|██████████| 802k/802k [00:00<00:00, 18.3MB/s]
# Downloading vocab.json: 100%|██████████| 1.59M/1.59M [00:00<00:00, 31.4MB/s]
# Downloading tokenizer_config.json: 100%|██████████| 44.0/44.0 [00:00<00:00, 200kB/s]

# %%
# TODO 4: Update the code below

# Filter reviews in French and translate to English
fr_reviews = df[df['Original Language'] == 'fr']['Review']
fr_reviews_en = fr_reviews.apply(lambda x: translate(x, model=fr_en_model, tokenizer=fr_en_tokenizer))

# Filter synopsis in French and translate to English
fr_synopsis = df[df['Original Language'] == 'fr']['Synopsis']
fr_synopsis_en = fr_synopsis.apply(lambda x: translate(x, model=fr_en_model, tokenizer=fr_en_tokenizer))

# Filter reviews in Spanish and translate to English
es_reviews = df[df['Original Language'] == 'sp']['Review']
es_reviews_en = es_reviews.apply(lambda x: translate(x, model=es_en_model, tokenizer=es_en_tokenizer))

# Filter synopsis in Spanish and translate to English
es_synopsis = df[df['Original Language'] == 'sp']['Synopsis']
es_synopsis_en = es_synopsis.apply(lambda x: translate(x, model=es_en_model, tokenizer=es_en_tokenizer))

# Update dataframe with translated text
df.loc[df['Original Language'] == 'fr', 'Review'] = fr_reviews_en
df.loc[df['Original Language'] == 'fr', 'Synopsis'] = fr_synopsis_en
df.loc[df['Original Language'] == 'sp', 'Review'] = es_reviews_en
df.loc[df['Original Language'] == 'sp', 'Synopsis'] = es_synopsis_en
# Out:
# /opt/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1288: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
df.sample(10)
# Out:
#                                   Title  Year  \
# 16       La Tour Montparnasse Infernale  2001
# 11                         Intouchables  2011
# 8               Solo: A Star Wars Story  2018
# 12                               Amélie  2001
# 27                               El Bar  2017
# 0             The Shawshank Redemption   1994
# 22                    Y tu mamá también  2001
# 14  Le Fabuleux Destin d'Amélie Poulain  2001
# 2                          Forrest Gump  1994
# 1                      The Dark Knight   2008
#
#                                              Synopsis  \
# 16  Two incompetent office workers find themselves...
# 11  This film tells the story of the unlikely frie...
# 8   A young Han Solo (Alden Ehrenreich) joins a gr...
# 12  This romantic comedy tells the story of Amélie...
# 27  A group of people are trapped in a bar after M...
# 0   Andy Dufresne (Tim Robbins), a successful bank...
# 22  Two teenage friends (Gael García Bernal and Di...
# 14  This romantic comedy tells the story of Amélie...
# 2   Forrest Gump (Tom Hanks) is a simple man with ...
# 1   Batman (Christian Bale) teams up with District...
#
#                                                Review Original Language
# 16  "I can't believe I've wasted time watching thi...                fr
# 11  "Untouchables is an incredibly touching film w...                fr
# 8   "Dull and pointless, with none of the magic of...                en
# 12  "Amélie is an absolutely charming film that wi...                fr
# 27  "The Bar is a ridiculous and meaningless film ...                sp
# 0   "The Shawshank Redemption is an inspiring tale...                en
# 22  "And your mom is also a movie that stays with ...                sp
# 14  "The Fabulous Destiny of Amélie Poulain is an ...                fr
# 2   "Forrest Gump is a heartwarming and inspiratio...                en
# 1   "The Dark Knight is a thrilling and intense su...                en

# %% [markdown]
# ### Sentiment Analysis
#
# Use HuggingFace pretrained model for sentiment analysis of the reviews. Store the sentiment result **Positive** or **Negative** in a new column titled **Sentiment** in the dataframe.

# %%
# TODO 5: Update the code below
# load sentiment analysis model
model_name = 'distilbert-base-uncased-finetuned-sst-2-english'
sentiment_classifier = pipeline("sentiment-analysis", model=model_name)

# TODO 6: Complete the function below
def analyze_sentiment(text, classifier):
    """
    function to perform sentiment analysis on a text using a model
    """
    result = classifier(text)[0]
    return result['label']
# Out:
# Downloading config.json: 100%|██████████| 629/629 [00:00<00:00, 2.23MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 268M/268M [00:01<00:00, 136MB/s]
# Downloading tokenizer_config.json: 100%|██████████| 48.0/48.0 [00:00<00:00, 190kB/s]
# Downloading vocab.txt: 100%|██████████| 232k/232k [00:00<00:00, 2.80MB/s]

# %%
# TODO 7: Add code below for sentiment analysis
# Perform sentiment analysis on reviews and store results in new column
df['Review Sentiment'] = df['Review'].apply(lambda x: analyze_sentiment(x, sentiment_classifier))

# %%
df.sample(10)
# Out:
#                                   Title  Year  \
# 13                        Les Choristes  2004
# 19                         Babylon A.D.  2008
# 0             The Shawshank Redemption   1994
# 5                     Blade Runner 2049  2017
# 1                      The Dark Knight   2008
# 24                        Amores perros  2000
# 23               El Laberinto del Fauno  2006
# 26                              Toc Toc  2017
# 14  Le Fabuleux Destin d'Amélie Poulain  2001
# 10                           La La Land  2016
#
#                                              Synopsis  \
# 13  This film tells the story of a music teacher w...
# 19  In the distant future, a mercenary has to esco...
# 0   Andy Dufresne (Tim Robbins), a successful bank...
# 5   Officer K (Ryan Gosling), a new blade runner f...
# 1   Batman (Christian Bale) teams up with District...
# 24  Three stories intertwine in this Mexican film:...
# 23  During the Spanish postwar period, Ofelia (Iva...
# 26  In this Spanish comedy, a group of people with...
# 14  This romantic comedy tells the story of Amélie...
# 10  This musical tells the story of a budding actr...
#
#                                                Review Original Language  \
# 13  "The Choristes are a beautiful film that will ...                fr
# 19  "This film is a complete mess. The characters ...                fr
# 0   "The Shawshank Redemption is an inspiring tale...                en
# 5   "Boring and too long. Nothing like the origina...                en
# 1   "The Dark Knight is a thrilling and intense su...                en
# 24  "Amores dogs is an intense and moving film tha...                sp
# 23  "The Labyrinth of Fauno is a fascinating and e...                sp
# 26  "Toc Toc is a boring and unoriginal film that ...                sp
# 14  "The Fabulous Destiny of Amélie Poulain is an ...                fr
# 10  "The Land is an absolutely beautiful film with...                fr
#
#    Review Sentiment
# 13         POSITIVE
# 19         NEGATIVE
# 0          POSITIVE
# 5          NEGATIVE
# 1          POSITIVE
# 24         POSITIVE
# 23         POSITIVE
# 26         NEGATIVE
# 14         POSITIVE
# 10         POSITIVE

# %%
# export the results to a .csv file
df.to_csv("reviews_with_sentiment.csv", index=False)
